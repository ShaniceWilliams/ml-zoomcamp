# %% [markdown]
# # Module 3: Churn Prediction Project

# %%
# imports
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 
import seaborn as sns
from pypalettes import load_cmap

# %matplotlib inline
cmap = load_cmap("X84")
palette = cmap.colors

# %% [markdown]
# ## 3.2 Data Preparation
#
# In this section we will prepare the data before we make any test train splits. This involves updating any formatting and making adjustments to data types of columns.

# %%
data_path = "./data/Customer-Churn-Dataset.csv"

# %%
df = pd.read_csv(data_path)

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head().T
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# ...

# %% [markdown]
# We are going to do a similar transformation of the column names and categorical features so there is consistency in formatting.

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

categorical_columns = list(df.dtypes[df.dtypes == 'object'].index)

for col in categorical_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head().T
# Out:
#                                  0             1               2  \
# customerid              7590-vhveg    5575-gnvde      3668-qpybk
# gender                      female          male            male
# seniorcitizen                    0             0               0
# partner                        yes            no              no
# dependents                      no            no              no
# tenure                           1            34               2
# phoneservice                    no           yes             yes
# multiplelines     no_phone_service            no              no
# internetservice                dsl           dsl             dsl
# onlinesecurity                  no           yes             yes
# onlinebackup                   yes            no             yes
# deviceprotection                no           yes              no
# techsupport                     no            no              no
# ...

# %%
df.dtypes
# Out:
# customerid           object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges         object
# churn                object
# dtype: object

# %% [markdown]
# We can identify that senior citizen is a categorical column even though it's a `int` data type.  We can also determine that `totalcharges` should be a float type but there is something that is stopping this.
#
# They used spaces to replace null values and we replaced those with `_`.

# %%
df.totalcharges
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: totalcharges, Length: 7043, dtype: object

# %%
#pd.to_numeric(df.totalcharges)

# %%
pd.to_numeric(df.totalcharges, errors='coerce')
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: totalcharges, Length: 7043, dtype: float64

# %%
tc = pd.to_numeric(df.totalcharges, errors='coerce')

# %%
df[tc.isnull()].T
# Out:
#                                        488                  753   \
# customerid                       4472-lvygi           3115-czmzd
# gender                               female                 male
# seniorcitizen                             0                    0
# partner                                 yes                   no
# dependents                              yes                  yes
# tenure                                    0                    0
# phoneservice                             no                  yes
# multiplelines              no_phone_service                   no
# internetservice                         dsl                   no
# onlinesecurity                          yes  no_internet_service
# onlinebackup                             no  no_internet_service
# deviceprotection                        yes  no_internet_service
# techsupport                             yes  no_internet_service
# ...

# %% [markdown]
# _Could we use the average term length of the data set and the monthly spend of those missing total spend to impute a total spend instead of just replacing with zero?_

# %%
df.totalcharges = pd.to_numeric(df.totalcharges, errors='coerce')

# %%
df.totalcharges = df.totalcharges.fillna(0)

# %% [markdown]
# ### Target Variable Prep
#
# We need to convert the churn column from object to 0 or 1 for binary classification.
#
# We do this by creating a mask that provides true and false values for each element of the series which can then be converted to an int type.

# %%
df.churn
# Out:
# 0        no
# 1        no
# 2       yes
# 3        no
# 4       yes
#        ...
# 7038     no
# 7039     no
# 7040     no
# 7041    yes
# 7042     no
# Name: churn, Length: 7043, dtype: object

# %%
df.churn == 'yes'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041     True
# 7042    False
# Name: churn, Length: 7043, dtype: bool

# %%
df.churn = (df.churn == 'yes').astype(int)

# %% [markdown]
# ## 3.3 Setting up the validation framework
#
# In this section we will perform the train validation test split using the scikit learn method `train_test_split`.

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)

# %%
len(df_full_train), len(df_test)
# Out:
# (5634, 1409)

# %%
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (4225, 1409, 1409)

# %%
df_train
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 3897  8015-ihcgw  female              0     yes        yes      72
# 1980  1960-uycnn    male              0      no         no      10
# 6302  9250-wypll  female              0      no         no       5
# 727   6786-obwqr  female              0     yes        yes       5
# 5104  1328-euzhc  female              0     yes         no      18
# ...          ...     ...            ...     ...        ...     ...
# 3774  1309-xgfsn    male              1     yes        yes      52
# 6108  4819-hjpiw    male              0      no         no      18
# 1530  3703-vavcl    male              0     yes        yes       2
# 3701  3812-lrzir  female              0     yes        yes      27
# 4368  1704-nrwye  female              1      no         no       9
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 3897          yes               yes     fiber_optic                  yes  ...
# ...

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
df_train
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 0     8015-ihcgw  female              0     yes        yes      72
# 1     1960-uycnn    male              0      no         no      10
# 2     9250-wypll  female              0      no         no       5
# 3     6786-obwqr  female              0     yes        yes       5
# 4     1328-euzhc  female              0     yes         no      18
# ...          ...     ...            ...     ...        ...     ...
# 4220  1309-xgfsn    male              1     yes        yes      52
# 4221  4819-hjpiw    male              0      no         no      18
# 4222  3703-vavcl    male              0     yes        yes       2
# 4223  3812-lrzir  female              0     yes        yes      27
# 4224  1704-nrwye  female              1      no         no       9
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 0             yes               yes     fiber_optic                  yes  ...
# ...

# %%
y_train = df_train.churn.values
y_val = df_val.churn.values
y_test = df_test.churn.values

# %%
del df_train['churn']
del df_val['churn']
del df_test['churn']

# %% [markdown]
# ## 3.4 EDA
#
# In this section we will check missing values, explore the target variable, and explore the numerical and categorical features.

# %%
df_full_train = df_full_train.reset_index(drop=True)

# %%
df_full_train.head().T
# Out:
#                                     0                        1  \
# customerid                 5442-pptjy               6261-rcvns
# gender                           male                   female
# seniorcitizen                       0                        0
# partner                           yes                       no
# dependents                        yes                       no
# tenure                             12                       42
# phoneservice                      yes                      yes
# multiplelines                      no                       no
# internetservice                    no                      dsl
# onlinesecurity    no_internet_service                      yes
# onlinebackup      no_internet_service                      yes
# deviceprotection  no_internet_service                      yes
# techsupport       no_internet_service                      yes
# streamingtv       no_internet_service                       no
# ...

# %% [markdown]
# ### Target variable exploration

# %%
df_full_train.churn.value_counts()
# Out:
# churn
# 0    4113
# 1    1521
# Name: count, dtype: int64

# %%
# as a percentage
df_full_train.churn.value_counts(normalize=True)
# Out:
# churn
# 0    0.730032
# 1    0.269968
# Name: proportion, dtype: float64

# %%
df_full_train.churn.mean()
# Out:
# np.float64(0.26996805111821087)

# %%
full_train_churn_rate = df_full_train.churn.mean()

# %% [markdown]
# Because the target varaiable is binary (0 or 1) the mean is the same as the churn rate as it counts the number of ones in the series.

# %% [markdown]
# ### Categorical Features

# %%
df_full_train.dtypes
# Out:
# customerid           object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges        float64
# churn                 int64
# dtype: object

# %%
categorical_columns = [
 'gender',
 'seniorcitizen',
 'partner',
 'dependents',
 'phoneservice',
 'multiplelines',
 'internetservice',
 'onlinesecurity',
 'onlinebackup',
 'deviceprotection',
 'techsupport',
 'streamingtv',
 'streamingmovies',
 'contract',
 'paperlessbilling',
 'paymentmethod',
]

# %%
df_full_train[categorical_columns].nunique()
# Out:
# gender              2
# seniorcitizen       2
# partner             2
# dependents          2
# phoneservice        2
# multiplelines       3
# internetservice     3
# onlinesecurity      3
# onlinebackup        3
# deviceprotection    3
# techsupport         3
# streamingtv         3
# streamingmovies     3
# contract            3
# paperlessbilling    2
# paymentmethod       4
# dtype: int64

# %% [markdown]
# ### Numerical Features

# %%
df_full_train.dtypes
# Out:
# customerid           object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges        float64
# churn                 int64
# dtype: object

# %%
numerical_cols = ['tenure', 'monthlycharges', 'totalcharges']

# %% [markdown]
# ## 3.5 Feature Importance: Churn Rate and risk ratio
#
# In this specific part of EDA we will explore which features have the most impact on our target variable.

# %%
df_full_train.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  5442-pptjy    male              0     yes        yes      12          yes
# 1  6261-rcvns  female              0      no         no      42          yes
# 2  2176-osjuv    male              0     yes         no      71          yes
# 3  6161-erdgd    male              0     yes        yes      71          yes
# 4  2364-ufrom    male              0      no         no      30          yes
#
#   multiplelines internetservice       onlinesecurity  ...  \
# 0            no              no  no_internet_service  ...
# 1            no             dsl                  yes  ...
# 2           yes             dsl                  yes  ...
# 3           yes             dsl                  yes  ...
# 4            no             dsl                  yes  ...
#
#       deviceprotection          techsupport          streamingtv  \
# 0  no_internet_service  no_internet_service  no_internet_service
# ...

# %%
churn_female = df_full_train[df_full_train.gender == 'female'].churn.mean()
churn_female
# Out:
# np.float64(0.27682403433476394)

# %%
full_train_churn_rate - churn_female
# Out:
# np.float64(-0.006855983216553063)

# %%
churn_male = df_full_train[df_full_train.gender == 'male'].churn.mean()
churn_male
# Out:
# np.float64(0.2632135306553911)

# %%
full_train_churn_rate - churn_male
# Out:
# np.float64(0.006754520462819769)

# %%
df_full_train.partner.value_counts()
# Out:
# partner
# no     2932
# yes    2702
# Name: count, dtype: int64

# %%
churn_partner = df_full_train[df_full_train.partner == 'yes'].churn.mean()
churn_partner
# Out:
# np.float64(0.20503330866025166)

# %%
churn_no_partner = df_full_train[df_full_train.partner == 'no'].churn.mean()
churn_no_partner
# Out:
# np.float64(0.3298090040927694)

# %%
full_train_churn_rate - churn_partner
# Out:
# np.float64(0.06493474245795922)

# %%
full_train_churn_rate - churn_no_partner
# Out:
# np.float64(-0.05984095297455855)

# %% [markdown]
# Here we can see a significant difference in churn rate for those customers with or without partners. When compared with the impact of gender there was very little difference. This tells us that partner may have more importance as a features in predicting churn than gender does.

# %% [markdown]
# ### Risk Ratio

# %%
churn_female / full_train_churn_rate
# Out:
# np.float64(1.0253955354648652)

# %%
churn_male / full_train_churn_rate
# Out:
# np.float64(0.9749802969838747)

# %%
churn_partner / full_train_churn_rate
# Out:
# np.float64(0.7594724924338315)

# %%
churn_no_partner / full_train_churn_rate
# Out:
# np.float64(1.2216593879412643)

# %%
df_full_train.groupby('gender').churn.agg(['mean', 'count'])
# Out:
#             mean  count
# gender
# female  0.276824   2796
# male    0.263214   2838

# %%
# To allow to print the result of the for loop each iteration
from IPython.display import display

# %%
# For each categorical variable find the churn rate and count of each category within, and then the two churn metrics
for category in categorical_columns:
    df_group = df_full_train.groupby(category).churn.agg(['mean', 'count'])
    df_group['diff'] = df_group['mean'] - full_train_churn_rate
    df_group['risk'] = df_group['mean'] / full_train_churn_rate
    display(df_group)
# Out:
#             mean  count      diff      risk
# gender
# female  0.276824   2796  0.006856  1.025396
# male    0.263214   2838 -0.006755  0.974980
#                    mean  count      diff      risk
# seniorcitizen
# 0              0.242270   4722 -0.027698  0.897403
# 1              0.413377    912  0.143409  1.531208
#              mean  count      diff      risk
# partner
# no       0.329809   2932  0.059841  1.221659
# yes      0.205033   2702 -0.064935  0.759472
#                 mean  count      diff      risk
# dependents
# no          0.313760   3968  0.043792  1.162212
# yes         0.165666   1666 -0.104302  0.613651
#                   mean  count      diff      risk
# phoneservice
# no            0.241316    547 -0.028652  0.893870
# yes           0.273049   5087  0.003081  1.011412
#                       mean  count      diff      risk
# multiplelines
# no                0.257407   2700 -0.012561  0.953474
# no_phone_service  0.241316    547 -0.028652  0.893870
# ...

# %% [markdown]
# From this we can see a number of variables seem to have a relation to the global churn rate, and so be important features. In the next section we will explore methods to score the feature importance.

# %% [markdown]
# ## 3.6 Feature Importance: Mutual Information
